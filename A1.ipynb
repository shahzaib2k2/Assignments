# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from matplotlib import pyplot

# %%
path = 'C:\\Users\\engrs\\jsrt_metadata.csv'
df = pd.read_csv("jsrt_metadata.csv")

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety     93
# size         93
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
df['diagnosis'].replace(np.nan, df['diagnosis'].value_counts().idxmax(), inplace=True)

# %%
df['size'].replace(np.nan, df['size'].astype(float).mean(), inplace=True)

# %%
df['position'].replace(np.nan, df['position'].value_counts().idxmax(), inplace=True)

# %%
df['y'].replace(np.nan, df['y'].astype(float).mean(), inplace=True)

# %%
df['x'].replace(np.nan, df['x'].astype(float).mean(), inplace=True)

# %%
df['subtlety'].replace(np.nan, df['subtlety'].astype(float).mean(), inplace=True)

# %%
#Question:1
df['diagnosis'].value_counts() 
plt.pyplot.xlabel("Disease")
plt.pyplot.ylabel("Patients")
plt.pyplot.hist(df['diagnosis'], color='red',ec='blue')
# Out:
# (array([167.,  33.,  13.,   5.,   8.,   7.,   3.,   3.,   4.,   4.]),
#  array([ 0. ,  3.1,  6.2,  9.3, 12.4, 15.5, 18.6, 21.7, 24.8, 27.9, 31. ]),
#  <BarContainer object of 10 artists>)

# %%
#Question:2
for i in list(df['diagnosis'].unique()):
    plt.pyplot.figure()
    plt.pyplot.pie(df[df['diagnosis'] == i]['state'].value_counts(),labels=list(df[df['diagnosis'] == i]['state'].value_counts().keys()),)
    df[df['diagnosis'] == i]['state'].value_counts()
# Out:
# C:\Users\engrs\AppData\Local\Temp/ipykernel_7116/1377291644.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.pyplot.figure()

# %%
#Question:3
for i in list(df['diagnosis'].unique()):
    plt.pyplot.figure()
    plt.pyplot.pie(df[df['diagnosis'] == i]['gender'].value_counts(),labels=list(df[df['diagnosis'] == i]['gender'].value_counts().keys()),)
    df[df['diagnosis'] == i]['gender'].value_counts()
# Out:
# C:\Users\engrs\AppData\Local\Temp/ipykernel_7116/1675247541.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.pyplot.figure()
